# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib notebook

# %%
# Load the data
c27_data = pd.read_csv('ROI_measurements_C27_021919.csv')

# %%
nunits = activities.shape[1]

# %%
# Get the ROI areas
area_cols = c27_data.columns[0::4]
activity_cols = c27_data.columns[1::4]
areas = np.array(c27_data[area_cols].iloc[0])
activities = c27_data[activity_cols]

def pair_correlation(i, j):
    '''Returns the correlation between the i'th unit and j'th unit'''
    return corr_matrix[i, j]

def find_correlates(i, threshold):
    '''Given unit i, find all units that correlate with it'''
    corr_units = []
    for j in range(nunits):
        if pair_correlation(i, j) > threshold:
            corr_units.append(j)
    return corr_units

pair_correlation(81, 83)
find_correlates(79, 0.7)
# Out:
# [31, 71, 72, 79, 80, 81, 82, 83]

# %% [markdown]
# ## Stimulus location and activity

# %% [markdown]
# Here, we gather the location of the stimulus and observe any difference between the activities of L/R

# %%
plt.figure(3)
plt.plot(activities.Mean81 + activities.Mean82 + activities.Mean83 +\
        activities.Mean80 + activities.Mean84)
# Out:
# <img src="data:image/png;base64,..." width="655">

# %%
pair_correlation(72,81)
# Out:
# 0.7730155354137673

# %%
plt.figure(3)
plt.hist(corr_matrix.flatten())
# Out:
# <img src="data:image/png;base64,..." width="432">
# (array([ 650., 2954., 7570., 2126.,  360.,  170.,  212.,  380.,  524.,
#          183.]),
#  array([-0.29261756, -0.1633558 , -0.03409405,  0.09516771,  0.22442947,
#          0.35369122,  0.48295298,  0.61221473,  0.74147649,  0.87073824,
#          1.        ]),
#  <a list of 10 Patch objects>)

# %%
corr_matrix = np.corrcoef(activities.T)

plt.figure(2)
plt.imshow(corr_matrix)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
np.correlate(activities.Mean81, activities.Mean83)
# Out:
# array([3.83976903e+08])

# %%
plt.plot(activities.Mean83)
plt.plot(activities.Mean81)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.plot()
# Out:
#       Area1    Mean1   X1   Y1  Area2     Mean2   X2     Y2  Area3    Mean3  \
# 0        32  327.094  113  143     34   353.618  130  151.5     21  315.333
# 1        32  187.156  113  143     34   144.853  130  151.5     21  169.905
# 2        32  283.375  113  143     34   287.000  130  151.5     21  293.048
# 3        32  349.438  113  143     34   261.735  130  151.5     21  251.190
# 4        32  551.312  113  143     34   611.324  130  151.5     21  602.381
# 5        32  453.406  113  143     34   541.882  130  151.5     21  299.619
# 6        32  297.469  113  143     34   444.794  130  151.5     21  258.905
# 7        32  284.688  113  143     34   300.176  130  151.5     21  264.238
# 8        32  343.594  113  143     34   381.706  130  151.5     21  360.810
# 9        32  382.156  113  143     34   552.441  130  151.5     21  382.810
# 10       32  307.312  113  143     34   488.912  130  151.5     21  273.857
# ...
